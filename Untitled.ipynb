# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker
import math



#-----
# set styles

mpl.rcParams['xtick.labelsize'] = 17
mpl.rcParams['ytick.labelsize'] = 17
mpl.rcParams['lines.linewidth'] = 2

#mpl.rcParams['font.sans-serif'].insert(0, 'Helvetica')

#sns.set(font="Helvetica")

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.size'] = 11
mpl.rcParams['text.usetex'] = False
mpl.rcParams['svg.fonttype'] = 'none'

my_dpi=150

#mpl.rcParams['pdf.fonttype'] = 42 # allows SVG text to be saved as editable

plt.style.use(['ggplot'])

from scipy.stats import norm

# %%
dfHR = pd.read_csv('csv/dfHR.csv', index_col=None)
dfHR.head()
# Out:
#                      Tm  W  L  WLperc   GB          Team    League Division  \
# 0   Los Angeles Dodgers  3  2   0.600   --       Dodgers  National     West
# 1      Seattle Mariners  6  1   0.857   --      Mariners  American     West
# 2     Oakland Athletics  4  3   0.571  2.0     Athletics  American     West
# 3   St. Louis Cardinals  2  3   0.400  2.0     Cardinals  National  Central
# 4  Arizona Diamondbacks  2  3   0.400  1.0  Diamondbacks  National     West
#
#      color tres    ...      wOBA  wRCplus  WARbat   ERA   SV    IP  BABIP  \
# 0  #8FBC8B  LAD    ...     0.429    153.0     2.5  4.78  1.0  49.0  0.287
# 1  #8FBC8B  SEA    ...     0.387    175.0     3.5  3.68  5.0  66.0  0.274
# 2  #8FBC8B  OAK    ...     0.313    116.0     1.3  3.00  2.0  66.0  0.210
# 3  #8FBC8B  STL    ...     0.331     97.0     0.7  4.70  1.0  44.0  0.246
# 4  #8FBC8B  ARI    ...     0.346    103.0     1.0  8.02  2.0  46.0  0.289
#
#     FIP  xFIP  WARpitch
# 0  4.08  3.51       0.8
# 1  4.30  4.57       0.0
# 2  3.74  4.97       0.6
# 3  5.85  4.54      -0.4
# 4  7.92  5.94      -0.7
#
# [5 rows x 26 columns]

# %%
plt.figure()
plt.xlim(0, 300)
g = sns.barplot(
    x='HR',
    y='Team',
    data=dfHR,
    palette=dfHR['color']
)
plt.plot([266, 266], [-10, 30], color="#FF9C00", linewidth=2)
g.figure.set_size_inches(8,14)
g.set_ylabel('TEAM', fontsize=16, fontweight='bold')
g.set_xlabel('HOME RUNS', fontsize=16, fontweight='bold')
# placing the bar labels
for p in g.patches:
    width = math.ceil( p.get_width() )
    g.text(width*1.04, p.get_y() + p.get_height()/1.25,
            "{:" ">6}".format( width ),
            fontsize=15, color="black", fontweight='bold', zorder=10)
g.figure.savefig('csv/HRtest.png',bbox_inches='tight',dpi=my_dpi)
plt.close()
